# %%
import numpy as np

# %%
class PCA:
    def __init__(self, n_components):
        self.n_components = n_components
        self.components = None
        self.mean = None

    def fit(self, X):
        # mean centering data 
        self.mean = np.mean(X, axis=0)
        X = X - self.mean
        
        # covariance ,functions needs samples as columns
        cov = np.cov(X.T)

        #eigenvalues,eigenvectors
        eigenvectors, eigenvalues = np.linalg.eig(cov)

        # eigenvectors v = [:, i] column vector, transpose this for easier calculations
        eigenvectors = eigenvectors.T

        # sort eigenvectors
        idxs = np.argsort(eigenvalues)[::-1]
        eigenvalues = eigenvalues[idxs]
        eigenvector = eigenvectors[idxs]
        self.components = eigenvectors[idxs][:self.n_components]
         
    def transform(self, X):
        # project data 
        X = X - self.mean
        return np.dot(X, self.components.T)

# %% [markdown]
# # Implementation

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
data = datasets.load_diabetes()
X = data.data
y = data.target

# Project the data onto the 2 primary principal components
pca = PCA(2)
pca.fit(X)
X_projected = pca.transform(X)

print("Shape of X:", X.shape)
print("Shape of transformed X:", X_projected.shape)

x1 = X_projected[:, 0]
x2 = X_projected[:, 1]

plt.scatter(
    x1,x2,c=y,edgecolor="none",alpha=0.8, cmap=plt.cm.get_cmap("viridis", 3)
)

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.colorbar()
plt.show()
# Out:
# Shape of X: (442, 10)
# Shape of transformed X: (442, 2)
# C:\Users\vipul\AppData\Local\Temp\ipykernel_17920\148326693.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   x1,x2,c=y,edgecolor="none",alpha=0.8, cmap=plt.cm.get_cmap("viridis", 3)
